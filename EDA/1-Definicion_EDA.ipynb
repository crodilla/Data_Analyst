# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %% [markdown]
# # Variabilidad genética del gen <i>CRB1</i> en población general

# %% [markdown]
# ### TEMA

# %% [markdown]
# Las distrofias de retina (DR) son un grupo de enfermedades raras que presentan alta variabilidad clínica y genética. El gen <i>CRB1</i> codifica para una proteína expresada en los fotorreceptores de la retina. Variaciones en este locus son causantes de Amaurosis Congénita de Leber (LCA) y Retinitis Pigmentosa (RP) en más de 80.000 personas a nivel mundial. Comprender la variabilidad genética existente en este locus permitirá identificar dianas para el desarrollo de nuevas terapias para estos pacientes.
#
# Para ello se ha hecho uso de distintas bases de datos públicas:
# - <b>GnomAD</b>: recoge las variantes identificadas y sus correspondientes frecuencias de proyectos mundiales de secuenciación del genoma humano.
# - <b>ClinVar</b>: es un repositorio de variantes junto al criterio de patogenicidad asociado a una cierta enfermedad.
# - <b>LOVD</b>: recopila información sobre la variación génica, así como aportar información del propio gen.

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Puede que tengas más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %% [markdown]
# <font size = 5><b>La frecuencia y distribución de las variantes del gen <i>CRB1</i> en población general siguen un patrón de variabilidad genética que se puede asociar a enfermedad visual</b></font>

# %% [markdown]
# 1. La variabilidad poblacional nos permite identificar posiciones críticas en <b>CRB1</b>
# 2. La variabilidad es mayor en población de origen europeo que en otras poblaciones
# 3. No hay diferencias de variabilidad genética entre géneros
# 4.

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una breve descripción del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
# describe la fuente de tus datos e incluye los links en Markdown

# %%
import pandas as pd

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %% [markdown]
# # GnomAD
# Se ha realizado una query en BigQuery (bigquery-public-data.gnomAD) donde está un acceso público a este repositorio para obtener los datos referentes al gen <i>CRB1</i>.

# %%
gnomad_crb1 = pd.read_json("GnomAD/Databases/Gnomad_crb1.json", lines = True)
gnomad_crb1.head()
# Out:
#    CHROM  START_POS    END_POS           dbSNP  REF ALT  AC        AF TYPE
# 0      1  197241517  197241518  [rs1335507706]    G   C   1  0.000032  snv  \
# 1      1  197239998  197239999  [rs1318432555]    C   T   1  0.000032  snv
# 2      1  197240222  197240225  [rs1383439447]  GGA   G   1  0.000032  del
# 3      1  197239286  197239287   [rs945705379]    A   G   5  0.000159  snv
# 4      1  197241224  197241225  [rs1322562610]    G   T   1  0.000032  snv
#
#   CANONICAL  ... AF_seu    AF_onf AF_amr    AF_afr AF_eas    AF_asj  AF_oth
# 0       YES  ...    0.0  0.000000    0.0  0.000115    0.0  0.000000     0.0  \
# 1       YES  ...    0.0  0.000000    0.0  0.000000    0.0  0.000000     0.0
# 2       YES  ...    0.0  0.000469    0.0  0.000000    0.0  0.000000     0.0
# 3       YES  ...    0.0  0.000000    0.0  0.000229    0.0  0.006897     0.0
# 4       YES  ...    0.0  0.000468    0.0  0.000000    0.0  0.000000     0.0
#
#     AF_male  AF_female  EXON
# ...

# %% [markdown]
# # ClinVar
# Repositorio de variantes asociadas a enfermedad de origen genético, (https://www.ncbi.nlm.nih.gov/clinvar/?term=crb1%5Bgene%5D&redir=gene).

# %%
clinvar_crb1 = pd.read_csv("GnomAD/clinvar_result.txt", sep='\t')
clinvar_crb1.head()
# Out:
#                                    Name Gene(s) Protein change
# 0           NM_201253.2(CRB1):c.-204C>T    CRB1            NaN  \
# 1           NM_201253.2(CRB1):c.-195G>A    CRB1            NaN
# 2            NM_201253.3(CRB1):c.-56C>G    CRB1            NaN
# 3            NM_201253.3(CRB1):c.-55C>T    CRB1            NaN
# 4  NM_201253.3(CRB1):c.4G>A (p.Ala2Thr)    CRB1            A2T
#
#                                         Condition(s)
# 0  Retinitis pigmentosa|Pigmented paravenous reti...  \
# 1  Retinitis pigmentosa|Pigmented paravenous reti...
# 2  Retinitis pigmentosa|Leber congenital amaurosi...
# 3  Pigmented paravenous retinochoroidal atrophy|L...
# 4  Leber congenital amaurosis 8|Retinitis pigment...
#
#                Clinical significance (Last reviewed)
# 0  Uncertain significance(Last reviewed: Jan 13, ...  \
# 1  Uncertain significance(Last reviewed: Jan 13, ...
# 2  Uncertain significance(Last reviewed: Apr 27, ...
# ...

# %% [markdown]
# # LOVD
# Este es otro repositorio de varianes que incluye información del gen, incluyendo una tabla que hace referencia a las posiciones de dicho tránscrito que pertenecen a regiones exónicas o intrónicas utilizada en este proyecto.

# %%
table = pd.read_html('https://databases.lovd.nl/shared/refseq/CRB1_NM_201253.2_table.html')
table[0].head()
# Out:
#    exon  c.startExon c.endExon  g.startExon  g.endExon  lengthExon
# 0     1         -209        70         4927       5205         279  \
# 1     2           71       652        65145      65726         582
# 2     3          653       848        81004      81199         196
# 3     4          849       988        84063      84202         140
# 4     5          989      1171        93554      93736         183
#
#    lengthIntron
# 0       59939.0
# 1       15277.0
# 2        2863.0
# 3        9351.0
# 4       63986.0
